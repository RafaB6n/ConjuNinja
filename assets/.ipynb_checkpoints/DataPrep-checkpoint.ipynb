# %%
# Import the pandas library  
import pandas as pd  
  
# Define the path to your CSV file  
csv_file_path = 'jehle_verb_database.csv'  # Please replace with your actual file path  
  
# Use the read_csv function from pandas to read the CSV file  
df = pd.read_csv(csv_file_path)

# %%
df.head(20)
# Out:
#    infinitive                                 infinitive_english  \
# 0   abandonar  to abandon, leave behind, desert; to quit, giv...
# 1   abandonar  to abandon, leave behind, desert; to quit, giv...
# 2   abandonar  to abandon, leave behind, desert; to quit, giv...
# 3   abandonar  to abandon, leave behind, desert; to quit, giv...
# 4   abandonar  to abandon, leave behind, desert; to quit, giv...
# 5   abandonar  to abandon, leave behind, desert; to quit, giv...
# 6   abandonar  to abandon, leave behind, desert; to quit, giv...
# 7   abandonar  to abandon, leave behind, desert; to quit, giv...
# 8   abandonar  to abandon, leave behind, desert; to quit, giv...
# 9   abandonar  to abandon, leave behind, desert; to quit, giv...
# 10  abandonar  to abandon, leave behind, desert; to quit, giv...
# 11  abandonar  to abandon, leave behind, desert; to quit, giv...
# 12  abandonar  to abandon, leave behind, desert; to quit, giv...
# 13  abandonar  to abandon, leave behind, desert; to quit, giv...
# 14  abandonar  to abandon, leave behind, desert; to quit, giv...
# 15  abandonar  to abandon, leave behind, desert; to quit, giv...
# 16  abandonar  to abandon, leave behind, desert; to quit, giv...
# 17  abandonar  to abandon, leave behind, desert; to quit, giv...
# 18    abordar  to board, get on [plane, bus, etc.]; to approa...
# 19    abordar  to board, get on [plane, bus, etc.]; to approa...
#
#                      mood            mood_english                 tense  \
# 0              Indicativo              Indicative              Presente
# 1              Indicativo              Indicative                Futuro
# 2              Indicativo              Indicative            Imperfecto
# 3              Indicativo              Indicative             Pretérito
# 4              Indicativo              Indicative           Condicional
# 5              Indicativo              Indicative     Presente perfecto
# 6              Indicativo              Indicative       Futuro perfecto
# 7              Indicativo              Indicative      Pluscuamperfecto
# 8              Indicativo              Indicative    Pretérito anterior
# 9              Indicativo              Indicative  Condicional perfecto
# 10             Subjuntivo             Subjunctive              Presente
# 11             Subjuntivo             Subjunctive            Imperfecto
# 12             Subjuntivo             Subjunctive                Futuro
# 13             Subjuntivo             Subjunctive     Presente perfecto
# 14             Subjuntivo             Subjunctive       Futuro perfecto
# 15             Subjuntivo             Subjunctive      Pluscuamperfecto
# 16  Imperativo Afirmativo  Imperative Affirmative              Presente
# 17    Imperativo Negativo     Imperative Negative              Presente
# 18             Indicativo              Indicative              Presente
# 19             Indicativo              Indicative                Futuro
#
#           tense_english                                  verb_english  \
# 0               Present                      I abandon, am abandoning
# 1                Future                                I will abandon
# 2             Imperfect  I was abandoning, used to abandon, abandoned
# 3             Preterite                                   I abandoned
# 4           Conditional                               I would abandon
# 5       Present Perfect                              I have abandoned
# 6        Future Perfect                         I will have abandoned
# 7          Past Perfect                               I had abandoned
# 8   Preterite (Archaic)                               I had abandoned
# 9   Conditional Perfect                        I would have abandoned
# 10              Present                      I abandon, am abandoning
# 11            Imperfect                   I abandoned, was abandoning
# 12               Future                                I will abandon
# 13      Present Perfect                   I have abandoned, abandoned
# 14       Future Perfect                         I will have abandoned
# 15         Past Perfect                               I had abandoned
# 16              Present                       Abandon! Don't abandon!
# 17              Present                       Abandon! Don't abandon!
# 18              Present                          I board, am boarding
# 19               Future                                  I will board
#
#                form_1s              form_2s             form_3s  \
# 0             abandono            abandonas            abandona
# 1           abandonaré          abandonarás          abandonará
# 2           abandonaba          abandonabas          abandonaba
# 3             abandoné          abandonaste            abandonó
# 4          abandonaría         abandonarías         abandonaría
# 5        he abandonado       has abandonado       ha abandonado
# 6     habré abandonado    habrás abandonado    habrá abandonado
# 7     había abandonado    habías abandonado    había abandonado
# 8      hube abandonado   hubiste abandonado     hubo abandonado
# 9    habría abandonado   habrías abandonado   habría abandonado
# 10            abandone            abandones            abandone
# 11          abandonara          abandonaras          abandonara
# 12          abandonare          abandonares          abandonare
# 13     haya abandonado     hayas abandonado     haya abandonado
# 14  hubiere abandonado  hubieres abandonado  hubiere abandonado
# 15  hubiera abandonado  hubieras abandonado  hubiera abandonado
# 16                 NaN             abandona           abandonad
# 17                 NaN         no abandones       no abandonéis
# 18              abordo              abordas              aborda
# 19            abordaré            abordarás            abordará
#
#                   form_1p               form_2p              form_3p  \
# 0             abandonamos            abandonáis            abandonan
# 1           abandonaremos          abandonaréis          abandonarán
# 2           abandonábamos          abandonabais          abandonaban
# 3             abandonamos         abandonasteis          abandonaron
# 4          abandonaríamos         abandonaríais         abandonarían
# 5        hemos abandonado     habéis abandonado       han abandonado
# 6     habremos abandonado    habréis abandonado    habrán abandonado
# 7     habíamos abandonado    habíais abandonado    habían abandonado
# 8      hubimos abandonado  hubisteis abandonado  hubieron abandonado
# 9    habríamos abandonado   habríais abandonado   habrían abandonado
# 10            abandonemos            abandonéis            abandonen
# 11          abandonáramos          abandonarais          abandonaran
# 12          abandonáremos          abandonareis          abandonaren
# 13     hayamos abandonado     hayáis abandonado     hayan abandonado
# 14  hubiéremos abandonado  hubiereis abandonado  hubieren abandonado
# 15  hubiéramos abandonado  hubierais abandonado  hubieran abandonado
# 16                    NaN              abandone            abandonen
# 17                    NaN           no abandone         no abandonen
# 18              abordamos              abordáis              abordan
# 19            abordaremos            abordaréis            abordarán
#
#          gerund gerund_english pastparticiple pastparticiple_english
# 0   abandonando     abandoning     abandonado              abandoned
# 1   abandonando     abandoning     abandonado              abandoned
# 2   abandonando     abandoning     abandonado              abandoned
# 3   abandonando     abandoning     abandonado              abandoned
# 4   abandonando     abandoning     abandonado              abandoned
# 5   abandonando     abandoning     abandonado              abandoned
# 6   abandonando     abandoning     abandonado              abandoned
# 7   abandonando     abandoning     abandonado              abandoned
# 8   abandonando     abandoning     abandonado              abandoned
# 9   abandonando     abandoning     abandonado              abandoned
# 10  abandonando     abandoning     abandonado              abandoned
# 11  abandonando     abandoning     abandonado              abandoned
# 12  abandonando     abandoning     abandonado              abandoned
# 13  abandonando     abandoning     abandonado              abandoned
# 14  abandonando     abandoning     abandonado              abandoned
# 15  abandonando     abandoning     abandonado              abandoned
# 16  abandonando     abandoning     abandonado              abandoned
# 17  abandonando     abandoning     abandonado              abandoned
# 18    abordando       boarding       abordado                boarded
# 19    abordando       boarding       abordado                boarded

# %%
# Create an empty dictionary to store the final result  
verbs_dict = {}  
  
# Iterate over each row in the dataframe  
for _, row in df.iterrows():  
    # Concatenate 'tense' and 'mood' to form the inner dictionary's key  
    inner_key = f'{row["tense"]} {row["mood"]}'  
    
    # Extract the verb forms as list  
    forms = [row[col] if row[col] else '' for col in df.columns if col.startswith('form_')]  
    forms = [f if type(f) is str else '' for f in forms]
    # Get the infinitive for the current row  
    infinitive = row['infinitive']  
  
    # Add this data to the verbs dictionary  
    if infinitive not in verbs_dict:
        verbs_dict[infinitive] = {inner_key: forms}  
    else:  
        verbs_dict[infinitive][inner_key] = forms

# %%
list(verbs_dict.keys())
# Out:
# ['abandonar',
#  'abordar',
#  'abortar',
#  'abrazar',
#  'abrir',
#  'aburrir',
#  'aburrirse',
#  'abusar',
#  'acabar',
#  'acampar',
#  'aceptar',
#  'acercar',
#  'acercarse',
#  'acompañar',
#  'acordar',
#  'aconsejar',
#  'acontecer',
#  'acordarse',
#  'acortar',
#  'acostar',
#  'acostarse',
#  'acostumbrar',
#  'actuar',
#  'acostumbrarse',
#  'adivinar',
#  'admirar',
#  'admitir',
#  'adorar',
#  'adornar',
#  'advertir',
#  'afirmar',
#  'afeitar',
#  'afeitarse',
#  'afligir',
#  'agorar',
#  'agradar',
#  'agradecer',
#  'aguantar',
#  'ahorcar',
#  'ahorrar',
#  'alcanzar',
#  'alegrar',
#  'alegrarse',
#  'alentar',
#  'aliviar',
#  'almorzar',
#  'alquilar',
#  'amanecer',
#  'amar',
#  'amenazar',
#  'andar',
#  'anhelar',
#  'anunciar',
#  'añadir',
#  'apagar',
#  'apoyar',
#  'aparecer',
#  'aplaudir',
#  'aplicar',
#  'apostar',
#  'apreciar',
#  'aprender',
#  'apretar',
#  'asistir',
#  'aprobar',
#  'arreglar',
#  'ayudar',
#  'arrepentirse',
#  'arrojar',
#  'asociar',
#  'aspirar',
#  'asustar',
#  'asustarse',
#  'atacar',
#  'atender',
#  'atraer',
#  'atravesar',
#  'atreverse',
#  'aumentar',
#  'avanzar',
#  'burlarse',
#  'averiguar',
#  'avisar',
#  'bajar',
#  'bañar',
#  'bañarse',
#  'barrer',
#  'batir',
#  'castigar',
#  'bautizar',
#  'beber',
#  'bendecir',
#  'bordar',
#  'borrar',
#  'brillar',
#  'charlar',
#  'brindar',
#  'broncearse',
#  'bucear',
#  'burlar',
#  'buscar',
#  'caber',
#  'caer',
#  'calcular',
#  'calentar',
#  'calentarse',
#  'callar',
#  'callarse',
#  'calmar',
#  'calmarse',
#  'caminar',
#  'cancelar',
#  'cansar',
#  'cansarse',
#  'comer',
#  'caracterizar',
#  'cargar',
#  'casar',
#  'cortar',
#  'casarse',
#  'causar',
#  'cazar',
#  'celebrar',
#  'cenar',
#  'censurar',
#  'cepillar',
#  'cerrar',
#  'cesar',
#  'chismear',
#  'chocar',
#  'civilizar',
#  'clarificar',
#  'clasificar',
#  'cobrar',
#  'cocinar',
#  'coger',
#  'colgar',
#  'colocar',
#  'colonizar',
#  'comprar',
#  'combatir',
#  'comenzar',
#  'competir',
#  'componer',
#  'comprender',
#  'comunicar',
#  'comunicarse',
#  'condenar',
#  'conducir',
#  'confesar',
#  'confiar',
#  'conquistar',
#  'confirmar',
#  'compartir',
#  'confiscar',
#  'conjugar',
#  'conocer',
#  'conseguir',
#  'consentir',
#  'conservar',
#  'consistir',
#  'constituir',
#  'construir',
#  'consumir',
#  'contaminar',
#  'contar',
#  'contener',
#  'contestar',
#  'continuar',
#  'contribuir',
#  'controlar',
#  'convencer',
#  'convenir',
#  'conversar',
#  'convertir',
#  'convidar',
#  'copiar',
#  'corregir',
#  'correr',
#  'coser',
#  'costar',
#  'crear',
#  'crecer',
#  'creer',
#  'criar',
#  'criarse',
#  'criticar',
#  'crucificar',
#  'cuidar',
#  'cruzar',
#  'cubrir',
#  'culpar',
#  'cultivar',
#  'cumplir',
#  'curar',
#  'dar',
#  'deber',
#  'decidir',
#  'decidirse',
#  'depender',
#  'decir',
#  'declarar',
#  'decorar',
#  'dedicar',
#  'dedicarse',
#  'defender',
#  'dejar',
#  'demostrar',
#  'depositar',
#  'deprimir',
#  'derretir',
#  'desagradar',
#  'desagradecer',
#  'desaparecer',
#  'desayunar',
#  'descansar',
#  'descender',
#  'describir',
#  'doler',
#  'descubrir',
#  'desarrollar',
#  'desarrollarse',
#  'desear',
#  'deshacer',
#  'despedir',
#  'despertar',
#  'despertarse',
#  'destruir',
#  'detener',
#  'detenerse',
#  'detestar',
#  'devolver',
#  'devorar',
#  'dibujar',
#  'dirigir',
#  'diseñar',
#  'disfrutar',
#  'disgustar',
#  'disminuir',
#  'distinguir',
#  'distribuir',
#  'divertir',
#  'divertirse',
#  'divorciar',
#  'divorciarse',
#  'doblar',
#  'dormir',
#  'dormirse',
#  'duchar',
#  'empezar',
#  'ducharse',
#  'dudar',
#  'durar',
#  'echar',
#  'echarse',
#  'educar',
#  'efectuar',
#  'ejercer',
#  'elegir',
#  'eliminar',
#  'emborrachar',
#  'emborracharse',
#  'emigrar',
#  'emplear',
#  'enamorar',
#  'enamorarse',
#  'encantar',
#  'encender',
#  'encontrar',
#  'enfadar',
#  'enfadarse',
#  'enfermar',
#  'enfermarse',
#  'entregar',
#  'enflaquecer',
#  'enflaquecerse',
#  'engañar',
#  'enojar',
#  'enojarse',
#  'enriquecer',
#  'enriquecerse',
#  'entrevistar',
#  'enseñar',
#  'ensuciar',
#  'entender',
#  'enterarse',
#  'entrar',
#  'entretener',
#  'entusiasmar',
#  'entusiasmarse',
#  'esconder',
#  'envejecer',
#  'envejecerse',
#  'enviar',
#  'gritar',
#  'equivocar',
#  'equivocarse',
#  'errar',
#  'escoger',
#  'esconderse',
#  'escribir',
#  'escuchar',
#  'fijar',
#  'esquiar',
#  'establecer',
#  'estar',
#  'estimar',
#  'estudiar',
#  'evacuar',
#  'evitar',
#  'exhibir',
#  'exigir',
#  'explicar',
#  'explorar',
#  'explotar',
#  'exponer',
#  'exportar',
#  'expresar',
#  'extender',
#  'extinguir',
#  'fabricar',
#  'faltar',
#  'fascinar',
#  'felicitar',
#  'fingir',
#  'firmar',
#  'florecer',
#  'formar',
#  'fortalecer',
#  'freír',
#  'fumar',
#  'funcionar',
#  'ganar',
#  'gastar',
#  'generalizar',
#  'glorificar',
#  'gobernar',
#  'graduar',
#  'graduarse',
#  'gruñir',
#  'guardar',
#  'guiar',
#  'gustar',
#  'hablar',
#  'hacer',
#  'hallar',
#  'hallarse',
#  'helar',
#  'heredar',
#  'herir',
#  'hervir',
#  'huir',
#  'ilustrar',
#  'importar',
#  'imprimir',
#  'incluir',
#  'indicar',
#  'inducir',
#  'influir',
#  'informar',
#  'iniciar',
#  'inmigrar',
#  'insultar',
#  'insistir',
#  'instalar',
#  'intentar',
#  'interesar',
#  'interpretar',
#  'introducir',
#  'invadir',
#  'inventar',
#  'invertir',
#  'investigar',
#  'invitar',
#  'invocar',
#  'ir',
#  'irse',
#  'jactarse',
#  'jugar',
#  'juntar',
#  'juntarse',
#  'jurar',
#  'ladrar',
#  'lamentar',
#  'lavar',
#  'lanzar',
#  'lastimar',
#  'lavarse',
#  'leer',
#  'legalizar',
#  'levantar',
#  'levantarse',
#  'limpiar',
#  'llamar',
#  'llamarse',
#  'llegar',
#  'llenar',
#  'llevar',
#  'llorar',
#  'llover',
#  'lograr',
#  'luchar',
#  'madurar',
#  'mandar',
#  'manejar',
#  'mantener',
#  'maquillar',
#  'maquillarse',
#  'marcar',
#  'masticar',
#  'matar',
#  'matricular',
#  'matricularse',
#  'medir',
#  'mentir',
#  'merecer',
#  'merendar',
#  'meter',
#  'mezclar',
#  'mirar',
#  'modificar',
#  'molestar',
#  'montar',
#  'morir',
#  'mostrar',
#  'mover',
#  'moverse',
#  'mudar(se)',
#  'mudarse',
#  'nacer',
#  'nadar',
#  'navegar',
#  'plantar',
#  'necesitar',
#  'negar',
#  'negarse',
#  'negociar',
#  'nevar',
#  'notar',
#  'obedecer',
#  'obligar',
#  'obtener',
#  'ocurrir',
#  'odiar',
#  'ofender',
#  'ofrecer',
#  'oír',
#  'oler',
#  'olvidar',
#  'olvidarse',
#  'oponer',
#  'oponerse',
#  'organizar',
#  'querer',
#  'padecer',
#  'pagar',
#  'parar',
#  'recoger',
#  'parecer',
#  'participar',
#  'pasar',
#  'patinar',
#  'pedir',
#  'pegar',
#  'peinar',
#  'peinarse',
#  'pelear',
#  'reinar',
#  'pensar',
#  'perder',
#  'perdonar',
#  'permanecer',
#  'permitir',
#  'perseguir',
#  'pertenecer',
#  'pesar',
#  'pescar',
#  'picar',
#  'pintar',
#  'platicar',
#  'planchar',
#  'poder',
#  'poner',
#  'ponerse',
#  'practicar',
#  'predecir',
#  'preferir',
#  'preguntar',
#  'preguntarse',
#  'prever',
#  'preparar',
#  'prepararse',
#  'presentir',
#  'preservar',
#  'probar',
#  'producir',
#  'prohibir',
#  'prometer',
#  'proponer',
#  'proseguir',
#  'proteger',
#  'protestar',
#  'provocar',
#  'publicar',
#  'purificar',
#  'quebrar',
#  'quebrarse',
#  'quedar',
#  'quedarse',
#  'quejarse',
#  'quemar',
#  'quemarse',
#  'realizar',
#  'rechazar',
#  'recibir',
#  'reciclar',
#  'recomendar',
#  'reconocer',
#  'recordar',
#  'renovar',
#  'reducir',
#  'regalar',
#  'regar',
#  'regatear',
#  'regir',
#  'registrar',
#  'registrarse',
#  'regresar',
#  'regular',
#  'rehusar',
#  'reír',
#  'renacer',
#  'renunciar',
#  'reñir',
#  'reparar',
#  'repasar',
#  'repetir',
#  'replicar',
#  'reportar',
#  'requerir',
#  'soler',
#  'reservar',
#  'resolver',
#  'respetar',
#  'respirar',
#  'responder',
#  'resultar',
#  'revelar',
#  'rezar',
#  'robar',
#  'rogar',
#  'romper',
#  'saber',
#  'sacar',
#  'sacrificar',
#  'sacudir',
#  'salir',
#  'saltar',
#  'sugerir',
#  'saludar',
#  'salvar',
#  'satisfacer',
#  'satirizar',
#  'secar',
#  'secarse',
#  'seguir',
#  'sentar',
#  'sentarse',
#  'sentir',
#  'sentirse',
#  'señalar',
#  'ser',
#  'servir',
#  'significar',
#  'simbolizar',
#  'situar',
#  'sobrevivir',
#  'sonar',
#  'soñar',
#  'sonreír',
#  'soportar',
#  'sorprender',
#  'subir',
#  'suceder',
#  'sufrir',
#  'suponer',
#  'surgir',
#  'suspirar',
#  'sustituir',
#  'tañer',
#  'tapar',
#  'tardar',
#  'temer',
#  'tener',
#  'teñir',
#  'terminar',
#  'tirar',
#  'tocar',
#  'tomar',
#  'torcer',
#  'toser',
#  'trabajar',
#  'traducir',
#  'traer',
#  'tragar',
#  'tratar',
#  'triunfar',
#  'tropezar',
#  'ubicar',
#  'unir',
#  'untar',
#  'usar',
#  'utilizar',
#  'vaciar',
#  'valer',
#  'variar',
#  'vencer',
#  'violar',
#  'vender',
#  'venir',
#  'ver',
#  'verificar',
#  'vestir',
#  'vestirse',
#  'viajar',
#  'visitar',
#  'vivir',
#  'volar',
#  'volver',
#  'vomit',
#  'votar',
#  'yacer',
#  'zambullirse',
#  'besar',
#  'bailar',
#  'presentar',
#  'esperar']

# %%
from collections import defaultdict

count = defaultdict(int)
for verb, conj in verbs_dict.items():
    count[len(conj)] += 1
print(count)
# Out:
# defaultdict(<class 'int'>, {18: 637})

# %%
from pprint import pprint

pprint(verbs_dict['apostar'])
# Out:
# {'Condicional Indicativo': ['apostaría',
#                             'apostarías',
#                             'apostaría',
#                             'apostaríamos',
#                             'apostaríais',
#                             'apostarían'],
#  'Condicional perfecto Indicativo': ['habría apostado',
#                                      'habrías apostado',
#                                      'habría apostado',
#                                      'habríamos apostado',
#                                      'habríais apostado',
#                                      'habrían apostado'],
#  'Futuro Indicativo': ['apostaré',
#                        'apostarás',
#                        'apostará',
#                        'apostaremos',
#                        'apostaréis',
#                        'apostarán'],
#  'Futuro Subjuntivo': ['apostare',
#                        'apostares',
#                        'apostare',
#                        'apostáremos',
#                        'apostareis',
#                        'apostaren'],
#  'Futuro perfecto Indicativo': ['habré apostado',
#                                 'habrás apostado',
#                                 'habrá apostado',
#                                 'habremos apostado',
#                                 'habréis apostado',
#                                 'habrán apostado'],
#  'Futuro perfecto Subjuntivo': ['hubiere apostado',
#                                 'hubieres apostado',
#                                 'hubiere apostado',
#                                 'hubiéremos apostado',
#                                 'hubiereis apostado',
#                                 'hubieren apostado'],
#  'Imperfecto Indicativo': ['apostaba',
#                            'apostabas',
#                            'apostaba',
#                            'apostábamos',
#                            'apostabais',
#                            'apostaban'],
#  'Imperfecto Subjuntivo': ['apostara',
#                            'apostaras',
#                            'apostara',
#                            'apostáramos',
#                            'apostarais',
#                            'apostaran'],
#  'Pluscuamperfecto Indicativo': ['había apostado',
#                                  'habías apostado',
#                                  'había apostado',
#                                  'habíamos apostado',
#                                  'habíais apostado',
#                                  'habían apostado'],
#  'Pluscuamperfecto Subjuntivo': ['hubiera apostado',
#                                  'hubieras apostado',
#                                  'hubiera apostado',
#                                  'hubiéramos apostado',
#                                  'hubierais apostado',
#                                  'hubieran apostado'],
#  'Presente Imperativo Afirmativo': ['',
#                                     'apuesta',
#                                     'apostad',
#                                     '',
#                                     'apueste',
#                                     'apuesten'],
#  'Presente Imperativo Negativo': ['',
#                                   'no apuestes',
#                                   'no apostéis',
#                                   '',
#                                   'no apueste',
#                                   'no apuesten'],
#  'Presente Indicativo': ['apuesto',
#                          'apuestas',
#                          'apuesta',
#                          'apostamos',
#                          'apostáis',
#                          'apuestan'],
#  'Presente Subjuntivo': ['apueste',
#                          'apuestes',
#                          'apueste',
#                          'apostemos',
#                          'apostéis',
#                          'apuesten'],
#  'Presente perfecto Indicativo': ['he apostado',
#                                   'has apostado',
#                                   'ha apostado',
#                                   'hemos apostado',
#                                   'habéis apostado',
#                                   'han apostado'],
#  'Presente perfecto Subjuntivo': ['haya apostado',
#                                   'hayas apostado',
#                                   'haya apostado',
#                                   'hayamos apostado',
#                                   'hayáis apostado',
#                                   'hayan apostado'],
#  'Pretérito Indicativo': ['aposté',
#                           'apostaste',
#                           'apostó',
#                           'apostamos',
#                           'apostasteis',
#                           'apostaron'],
#  'Pretérito anterior Indicativo': ['hube apostado',
#                                    'hubiste apostado',
#                                    'hubo apostado',
#                                    'hubimos apostado',
#                                    'hubisteis apostado',
#                                    'hubieron apostado']}

# %%
type(df.iloc[16]['form_1s'])
# Out:
# float

# %%
import json  
  
# specify the file name  
json_file = 'verbs_dict.json'  
  
# use the 'dump' method from the 'json' module to write the dictionary to a file  
with open(json_file, 'w') as file:  
    json.dump(verbs_dict, file)
